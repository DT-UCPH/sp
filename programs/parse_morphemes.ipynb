# %% [markdown]
# # Parsing morphemes
#
# This notebook contains scripts to extract SP morphemes from MT (whenever possible) and the predictions from the neural network model.
#
# The procedure is in three steps:
# 1. Imposing features from MT whenever the SP consonantal text and lexeme match MT
# 2. The remaining features are extracted from the neural network predictions
# 3. The data are merged with priority given to the data imposed from MT

# %%
import os
import pandas as pd
import numpy as np
import re
import collections

# %%
from tf.app import use
MT = use('etcbc/bhsa')
SP = use('DT-UCPH/sp:hot', hoist=globals())
# Out:
# <b title="local commit">TF-app:</b> <span title="#b83bcaee62ada4d03547df0b0e7aac2fd5de3f67 offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.7.3=#af70cebe9d23ea736bb40e3ccd6768875b52a49d offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#aba4367b49750089e4e4122415a77cac43bd97bc offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#f45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 10.2.6</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa TF-app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/0_home" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a><br><b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(atom) (det; und; NA.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/freq_lex.tf">freq_lex</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ frequency of lexemes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ syntactic function of phrase (Cmpl; Objc; Pred; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word.tf">g_word</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word_utf8.tf">g_word_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> 🆗 english translation of lexeme (beginning create god(s))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ grammatical gender (m; f; NA; unknown.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/label" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/label.tf">label</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ (half-)verse label (half verses: A; B; C; verses:  GEN 01,02)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/language.tf">language</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ of word or lexeme (Hebrew; Aramaic.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/lex.tf">lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme consonantal-transliterated (B R>CJT/ BR>[ >LHJM/)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/lex_utf8.tf">lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme consonantal-Hebrew (ב ראשׁית֜ ברא אלהים֜)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/ls" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/ls.tf">ls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexical set, subclassification of part-of-speech (card; ques; mult)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/nametyp
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# const copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <b title="latest commit">TF-app:</b> <span title="#781b71daed8b2cab93f27a5fa6b959092a9586ec">~/text-fabric-data/github/DT-UCPH/sp/app</span>
# <b title="local commit">data:</b> <span title="#781b71daed8b2cab93f27a5fa6b959092a9586ec offline under ~/text-fabric-data/github">~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2</span>
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 10.2.6</a>, <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/app" title="DT-UCPH/sp TF-app">DT-UCPH/sp/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/home.md" title="provenance of Samaritan Pentateuch - Genesis">SP</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/home.md" title="SP feature documentation">Feature docs</a><br><b>Features:</b><br>
# <details><summary><b>Samaritan Pentateuch - Genesis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/book.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book title</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/chapter.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_cons.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word consonantal-transliterated</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_cons_raw.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_cons_raw.tf">g_cons_raw</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word consonantal-transliterated (without disambiguation of Shin (C) and Sin (F))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_cons_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> word in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_nme.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_nme.tf">g_nme</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized nominal ending consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_nme_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_nme_utf8.tf">g_nme_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized nominal ending consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_pfm.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_pfm.tf">g_pfm</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal preformative consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_pfm_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_pfm_utf8.tf">g_pfm_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal preformative consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_prs.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_prs.tf">g_prs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized pronominal suffix consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_prs_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_prs_utf8.tf">g_prs_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized pronominal suffix consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_uvf.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_uvf.tf">g_uvf</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized univalent final</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_uvf_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_uvf_utf8.tf">g_uvf_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized univalent final in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_vbe.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_vbe.tf">g_vbe</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal ending consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_vbe_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_vbe_utf8.tf">g_vbe_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal ending consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_vbs.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_vbs.tf">g_vbs</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal stem consonantal</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/g_vbs_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/g_vbs_utf8.tf">g_vbs_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> realized verbal stem consonantal in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/gn.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/language.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/language.tf">language</a>
# </div>
# <div class="fmono">str</div>
#
# <span> language</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/lex.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/lex.tf">lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lexeme consonantal-transliterated</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/lex_utf8.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/lex_utf8.tf">lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lexeme in Hebrew script</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/docs/features/mt_feat.md" title="~/text-fabric-data/github/DT-UCPH/sp/tf/1.5.2/mt_feat.tf">mt_feat</a>
# </div>
# <div class="fmono">str</div>
#
# <span> features imposed from MT</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/ma
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# const copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %% [markdown]
# ## 1. g_cons to feature

# %%
FEATURE = 'g_lex'
MT.load(FEATURE)
# Out:
# True

# %%
def checkMT(ref, SPw, SPlex):
    
    bo, ch, ve = ref
    try:
        int(ve)
    except:
        return 'False'
    
    ref = MT.api.T.nodeFromSection((bo, int(ch), int(ve)))
    words = MT.api.L.d(ref, 'word')
    
    MT_feat = 'False'
    for w in words:
        if SPw == MT.api.F.g_cons.v(w) and SPlex == MT.api.F.lex.v(w):
            MT_feat =  eval(f"MT.api.F.{FEATURE}.v({w})")
            if MT_feat == '':
                MT_feat = 'absent'
            break
    
    return str(re.sub('[\_AEIOU\@\.\:\;\-]','',MT_feat))

# %%
MT_feat = []
MT_parsing = []

for w in SP.api.F.otype.s('word'):
    
    g_cons = SP.api.F.g_cons.v(w)
    lex = SP.api.F.lex.v(w)
    ref = SP.api.T.sectionFromNode(w)
    
    check_MT = checkMT(ref, g_cons, lex)
    MT_feat.append(check_MT)
    
    if check_MT == 'False':
        MT_parsing.append('')
    else:
        MT_parsing.append('True')

# %%
MT_feat
# Out:
# ['B',
#  'R>CJT',
#  'BR>',
#  '>LH',
#  '>T',
#  'H',
#  'CMJ',
#  'W',
#  '>T',
#  'H',
#  '>RY',
#  'W',
#  'H',
#  '>RY',
#  'HJ',
#  'THW',
#  'W',
#  'BHW',
#  'W',
#  'XCK',
#  '<L',
#  'PN',
#  'THWM',
#  'W',
#  'RWX',
#  '>LH',
#  'RXP',
#  '<L',
#  'PN',
#  'H',
#  'MJ',
#  'W',
#  '>MR',
#  '>LH',
#  'HJ',
#  '>WR',
#  'W',
#  'HJ',
#  '>WR',
#  'W',
#  'R>',
#  '>LH',
#  '>T',
#  'H',
#  '>WR',
#  'KJ',
#  'VWB',
#  'W',
#  'BDL',
#  '>LH',
#  'BJN',
#  'H',
#  '>WR',
#  'W',
#  'BJN',
#  'H',
#  'XCK',
#  'W',
#  'QR>',
#  '>LH',
#  'L',
#  '>WR',
#  'JWM',
#  'W',
#  'L',
#  'XCK',
#  'QR>',
#  'LJLH',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  '>XD',
#  'W',
#  '>MR',
#  '>LH',
#  'HJ',
#  'RQJ<',
#  'B',
#  'TWK',
#  'H',
#  'MJ',
#  'W',
#  'HJ',
#  'BDJL',
#  'BJN',
#  'MJ',
#  'L',
#  'MJ',
#  'W',
#  '<F',
#  '>LH',
#  '>T',
#  'H',
#  'RQJ<',
#  'W',
#  'BDL',
#  'BJN',
#  'H',
#  'MJ',
#  '>CR',
#  'M',
#  'TXT',
#  'L',
#  'RQJ<',
#  'W',
#  'BJN',
#  'H',
#  'MJ',
#  '>CR',
#  'M',
#  '<L',
#  'L',
#  'RQJ<',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  'QR>',
#  '>LH',
#  'L',
#  'RQJ<',
#  'CMJ',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  'CNJ',
#  'W',
#  '>MR',
#  '>LH',
#  'QW',
#  'H',
#  'MJ',
#  'M',
#  'TXT',
#  'H',
#  'CMJ',
#  '>L',
#  'MQWM',
#  '>XD',
#  'W',
#  'R>H',
#  'H',
#  'JBC',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  'QR>',
#  '>LH',
#  'L',
#  'JBC',
#  '>RY',
#  'W',
#  'L',
#  'MQWH',
#  'H',
#  'MJ',
#  'QR>',
#  'JM',
#  'W',
#  'R>',
#  '>LH',
#  'KJ',
#  'VWB',
#  'W',
#  '>MR',
#  '>LH',
#  'DC>',
#  'H',
#  '>RY',
#  'DC>',
#  '<FB',
#  'ZRJ<',
#  'ZR<',
#  'W',
#  '<Y',
#  'PRJ',
#  '<FH',
#  'PRJ',
#  'L',
#  'MJN',
#  '>CR',
#  'ZR<',
#  'B',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  'WY>',
#  'H',
#  '>RY',
#  'DC>',
#  '<FB',
#  'ZRJ<',
#  'ZR<',
#  'L',
#  'MJN',
#  'W',
#  '<Y',
#  '<FH',
#  'PRJ',
#  '>CR',
#  'ZR<',
#  'B',
#  'L',
#  'MJN',
#  'W',
#  'R>',
#  '>LH',
#  'KJ',
#  'VWB',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  'CLJCJ',
#  'W',
#  '>MR',
#  '>LH',
#  'HJ',
#  'False',
#  'B',
#  'RQJ<',
#  'H',
#  'CMJ',
#  'L',
#  'False',
#  'False',
#  'H',
#  'False',
#  'W',
#  'L',
#  'BDJL',
#  'BJN',
#  'H',
#  'JWM',
#  'W',
#  'BJN',
#  'H',
#  'LJLH',
#  'W',
#  'HJ',
#  'L',
#  'False',
#  'W',
#  'L',
#  'MW<D',
#  'W',
#  'L',
#  'JM',
#  'W',
#  'CN',
#  'W',
#  'HJ',
#  'L',
#  'False',
#  'B',
#  'RQJ<',
#  'H',
#  'CMJ',
#  'L',
#  '>JR',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  '<F',
#  '>LH',
#  '>T',
#  'CN',
#  'H',
#  'False',
#  'H',
#  'GDL',
#  '>T',
#  'H',
#  'M>WR',
#  'H',
#  'False',
#  'L',
#  'MMCL',
#  'H',
#  'JWM',
#  'W',
#  '>T',
#  'H',
#  'M>WR',
#  'H',
#  'QVN',
#  'L',
#  'MMCL',
#  'H',
#  'LJLH',
#  'W',
#  '>T',
#  'H',
#  'KWKB',
#  'W',
#  'TN',
#  '>T',
#  '>LH',
#  'B',
#  'RQJ<',
#  'H',
#  'CMJ',
#  'L',
#  '>JR',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  'L',
#  'MCL',
#  'B',
#  '',
#  'JWM',
#  'W',
#  'B',
#  'LJLH',
#  'W',
#  'L',
#  'BDJL',
#  'BJN',
#  'H',
#  '>WR',
#  'W',
#  'BJN',
#  'H',
#  'XCK',
#  'W',
#  'R>',
#  '>LH',
#  'KJ',
#  'VWB',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  'RBJ<J',
#  'W',
#  '>MR',
#  '>LH',
#  'CRY',
#  'H',
#  'MJ',
#  'CRY',
#  'NPC',
#  'XJ',
#  'W',
#  '<WP',
#  'False',
#  '<L',
#  'H',
#  '>RY',
#  '<L',
#  'PN',
#  'RQJ<',
#  'H',
#  'CMJ',
#  'W',
#  'BR>',
#  '>LH',
#  '>T',
#  'H',
#  'False',
#  'H',
#  'GDL',
#  'W',
#  '>T',
#  'KL',
#  'NPC',
#  'H',
#  'XJ',
#  'H',
#  'RMF',
#  '>CR',
#  'CRY',
#  'H',
#  'MJ',
#  'L',
#  'False',
#  'W',
#  '>T',
#  'KL',
#  '<WP',
#  'KNP',
#  'L',
#  'MJN',
#  'W',
#  'R>',
#  '>LH',
#  'KJ',
#  'VWB',
#  'W',
#  'BRK',
#  '>T',
#  '>LH',
#  'L',
#  '>MR',
#  'PR',
#  'W',
#  'RB',
#  'W',
#  'ML>',
#  '>T',
#  'H',
#  'MJ',
#  'B',
#  '',
#  'JM',
#  'W',
#  'H',
#  '<WP',
#  'False',
#  'B',
#  '>RY',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  'XMJCJ',
#  'W',
#  '>MR',
#  '>LH',
#  'WY>',
#  'H',
#  '>RY',
#  'NPC',
#  'XJ',
#  'L',
#  'MJN',
#  'BHM',
#  'W',
#  'RMF',
#  'W',
#  'False',
#  'H',
#  '>RY',
#  'L',
#  'MJN',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  '<F',
#  '>LH',
#  '>T',
#  'XJ',
#  'H',
#  '>RY',
#  'L',
#  'MJN',
#  'W',
#  '>T',
#  'H',
#  'BHM',
#  'L',
#  'MJN',
#  'W',
#  '>T',
#  'KL',
#  'RMF',
#  'H',
#  '>DM',
#  'L',
#  'MJN',
#  'W',
#  'R>',
#  '>LH',
#  'KJ',
#  'VWB',
#  'W',
#  '>MR',
#  '>LH',
#  '<FH',
#  '>DM',
#  'B',
#  'YLM',
#  'W',
#  'K',
#  'DMWT',
#  'W',
#  'RD',
#  'B',
#  'DG',
#  'H',
#  'JM',
#  'W',
#  'B',
#  '<WP',
#  'H',
#  'CMJ',
#  'W',
#  'B',
#  '',
#  'BHM',
#  'W',
#  'B',
#  'KL',
#  'H',
#  '>RY',
#  'W',
#  'B',
#  'KL',
#  'H',
#  'RMF',
#  'H',
#  'RMF',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  'BR>',
#  '>LH',
#  '>T',
#  'H',
#  '>DM',
#  'B',
#  'YLM',
#  'B',
#  'YLM',
#  '>LH',
#  'BR>',
#  '>T',
#  'ZKR',
#  'W',
#  'NQB',
#  'BR>',
#  '>T',
#  'W',
#  'BRK',
#  '>T',
#  '>LH',
#  'W',
#  '>MR',
#  'L',
#  '>LH',
#  'PR',
#  'W',
#  'RB',
#  'W',
#  'ML>',
#  '>T',
#  'H',
#  '>RY',
#  'W',
#  'False',
#  'W',
#  'RD',
#  'B',
#  'DG',
#  'H',
#  'JM',
#  'W',
#  'B',
#  '<WP',
#  'H',
#  'CMJ',
#  'W',
#  'B',
#  'KL',
#  'H',
#  'XJ',
#  'H',
#  'RMF',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  '>MR',
#  '>LH',
#  'HNH',
#  'NT',
#  'L',
#  '>T',
#  'KL',
#  '<FB',
#  'ZR<',
#  'ZR<',
#  '>CR',
#  '<L',
#  'PN',
#  'KL',
#  'H',
#  '>RY',
#  'W',
#  '>T',
#  'KL',
#  '<Y',
#  '>CR',
#  'B',
#  'PRJ',
#  '<Y',
#  'ZR<',
#  'ZR<',
#  'L',
#  'HJH',
#  'L',
#  '>KL',
#  'W',
#  'L',
#  'KL',
#  'XJ',
#  'H',
#  '>RY',
#  'W',
#  'L',
#  'KL',
#  '<WP',
#  'H',
#  'CMJ',
#  'W',
#  'L',
#  'KL',
#  'H',
#  'False',
#  '<L',
#  'H',
#  '>RY',
#  '>CR',
#  'B',
#  'NPC',
#  'XJ',
#  '>T',
#  'KL',
#  'JRQ',
#  '<FB',
#  'L',
#  '>KL',
#  'W',
#  'HJ',
#  'KN',
#  'W',
#  'R>',
#  '>LH',
#  '>T',
#  'KL',
#  '>CR',
#  '<FH',
#  'W',
#  'HNH',
#  'VWB',
#  'M>D',
#  'W',
#  'HJ',
#  '<RB',
#  'W',
#  'HJ',
#  'BQR',
#  'JWM',
#  'H',
#  'CCJ',
#  'W',
#  'KL',
#  'H',
#  'CMJ',
#  'W',
#  'H',
#  '>RY',
#  'W',
#  'KL',
#  'YB>',
#  'W',
#  'KL',
#  '>LH',
#  'B',
#  '',
#  'JWM',
#  'H',
#  'False',
#  'ML>K',
#  '>CR',
#  '<FH',
#  'W',
#  'CBT',
#  'B',
#  '',
#  'JWM',
#  'H',
#  'CBJ<J',
#  'M',
#  'KL',
#  'ML>K',
#  '>CR',
#  '<FH',
#  'W',
#  'BRK',
#  '>LH',
#  '>T',
#  'JWM',
#  'H',
#  'CBJ<J',
#  'W',
#  'QDC',
#  '>T',
#  'KJ',
#  'B',
#  'CBT',
#  'M',
#  'KL',
#  'ML>K',
#  '>CR',
#  'BR>',
#  '>LH',
#  'L',
#  '<F',
#  '>LH',
#  'False',
#  'H',
#  'CMJ',
#  'W',
#  'H',
#  '>RY',
#  'B',
#  'BR>',
#  'B',
#  'False',
#  'JWM',
#  '<F',
#  'JHWH',
#  '>LH',
#  'CMJ',
#  'W',
#  '>RY',
#  'W',
#  'KL',
#  'FJX',
#  'H',
#  'FDH',
#  'VRM',
#  'HJH',
#  'B',
#  '',
#  '>RY',
#  'W',
#  'KL',
#  '<FB',
#  'H',
#  'FDH',
#  'VRM',
#  'YMX',
#  'KJ',
#  'L>',
#  'MVJR',
#  'JHWH',
#  '>LH',
#  '<L',
#  'H',
#  '>RY',
#  'W',
#  '>DM',
#  '>JN',
#  'L',
#  '<BD',
#  '>T',
#  'H',
#  '>DM',
#  'W',
#  '>D',
#  '<LH',
#  'MN',
#  'H',
#  '>RY',
#  'W',
#  'CQH',
#  '>T',
#  'KL',
#  'PN',
#  'H',
#  '>DM',
#  'W',
#  'False',
#  'JHWH',
#  '>LH',
#  '>T',
#  'H',
#  '>DM',
#  '<PR',
#  'MN',
#  'H',
#  '>DM',
#  'W',
#  'PX',
#  'B',
#  '>P',
#  'NCM',
#  'XJ',
#  'W',
#  'HJ',
#  '>DM',
#  'L',
#  'NPC',
#  'XJ',
#  'W',
#  'V<',
#  'JHWH',
#  '>LH',
#  'GN',
#  'B',
#  '<DN',
#  'M',
#  'QDM',
#  'W',
#  'FM',
#  'CM',
#  '>T',
#  'H',
#  '>DM',
#  '>CR',
#  'JYR',
#  'W',
#  'YMX',
#  'JHWH',
#  '>LH',
#  'MN',
#  'H',
#  '>DM',
#  'False',
#  'KL',
#  '<Y',
#  'XMD',
#  'L',
#  'MR>H',
#  'W',
#  'VWB',
#  'L',
#  'M>KL',
#  'W',
#  '<Y',
#  'H',
#  'XJ',
#  'B',
#  'TWK',
#  'H',
#  'GN',
#  'W',
#  '<Y',
#  'H',
#  'D<',
#  'VWB',
#  'W',
#  'R<',
#  'W',
#  'NHR',
#  'JY>',
#  'M',
#  '<DN',
#  'L',
#  'CQ',
#  '>T',
#  'H',
#  'GN',
#  'W',
#  'M',
#  'CM',
#  'PRD',
#  'W',
#  'HJH',
#  'L',
#  '>RB<',
#  'R>C',
#  'CM',
#  'H',
#  '>XD',
#  'PJCWN',
#  'HW>',
#  'False',
#  '>T',
#  'KL',
#  '>RY',
#  'H',
#  'XWJLH',
#  '>CR',
#  'CM',
#  'H',
#  'ZHB',
#  'W',
#  'ZHB',
#  'H',
#  '>RY',
#  'H',
#  'False',
#  'VWB',
#  'False',
#  'CM',
#  'H',
#  'BDLX',
#  'W',
#  '>BN',
#  'H',
#  'CHM',
#  'W',
#  'CM',
#  'H',
#  'NHR',
#  'H',
#  'CNJ',
#  'GJXWN',
#  'HW>',
#  'H',
#  'SWBB',
#  '>T',
#  'KL',
#  '>RY',
#  'KWC',
#  'W',
#  'CM',
#  'H',
#  'NHR',
#  'H',
#  'CLJCJ',
#  'False',
#  'HW>',
#  'H',
#  'HLK',
#  'QDM',
#  '>CWR',
#  'W',
#  'H',
#  'NHR',
#  'H',
#  'RBJ<J',
#  'HW>',
#  'PRT',
#  'W',
#  'QX',
#  'JHWH',
#  '>LH',
#  '>T',
#  'H',
#  '>DM',
#  'W',
#  'False',
#  'B',
#  'GN',
#  '<DN',
#  'L',
#  '<BD',
#  'W',
#  'L',
#  'CMR',
#  'W',
#  'YW',
#  'JHWH',
#  '>LH',
#  '<L',
#  'H',
#  '>DM',
#  'L',
#  '>MR',
#  'M',
#  'KL',
#  '<Y',
#  'H',
#  'GN',
#  '>KL',
#  '>KL',
#  'W',
#  'M',
#  '<Y',
#  'H',
#  'D<',
#  'VWB',
#  'W',
#  'R<',
#  'L>',
#  '>KL',
#  'MMN',
#  'KJ',
#  'B',
#  'False',
#  'JWM',
#  '>KL',
#  'MMN',
#  'MWT',
#  'MWT',
#  'W',
#  ...]

# %%
n=0
e=0
for u in MT_feat:
    if u == 'False':
        e+=1
    n+=1
        
print(f"Lexemes matched: {round((n-e)/n*100, 2)}%")
# Out:
# Lexemes matched: 93.53%

# %% [markdown]
# ## 2. Probabilistic model to feature

# %% [markdown]
# #### Opdating prediction dataset

# %%
def TF2table():
    g_cons_string = ''
    for w in SP.api.F.otype.s('word'):
        if not SP.api.F.trailer.v(w):
            trailer = '-'
        else:
            trailer = ' '
        g_cons_string += f'{SP.api.F.g_cons.v(w)}{trailer}'
        
    return g_cons_string.split(' ')

# %%
data = pd.read_csv('./data/results_predictions_SP_input_corrected_09.11.22.txt', sep='\t', header=None)
data.columns = [0,'ref','raw','prediction']


g_cons_string = pd.DataFrame(TF2table())
data = pd.concat([data, g_cons_string], ignore_index=True, axis=1)
data.columns = [0, 'ref', 'raw', 'prediction', 'g_cons']

for n, row in data.iterrows():
    if len(row['g_cons'].split('-')) != len(row['prediction'].split('-')):
        display(row)
        display(data[data.ref == row['ref']])
        break

# %%
for n, row in data.iterrows():
    g_cons = re.sub('\-','',row['g_cons'])
    g_cons = re.sub('\_',' ', g_cons)
    g_cons = re.sub('F','C', g_cons)
    if g_cons != row['raw']:
        display(row)
        display(data[data.ref == row['ref']])
        break

# %% [markdown]
# #### Importing data

# %%
def g_nme(w):
    
    w = re.sub('\([A-Z]','', w) #Remove root letter
    w = re.search('/[A-Z]*', w)
    
    if w: return w.group()
    
def g_vbe(w):
    
    w = re.sub('\([A-Z]','', w) #Remove root letter
    w = re.search('\[[A-Z]*', w)
    
    if w: return w.group()
    
def g_pfm(w):
    
    w = re.search('!?[A-Z]*\!', w)
    
    if w:
   
        if w.group()[0] != '!': #For some reason, the predictions never prefix the preformative with an !
            return f"!{w.group()}"
        else:
            return w.group()
        
def g_vbs(w):

    w = re.sub('\([A-Z]','', w) #Remove root letter
    w = re.search('\\]?[A-Z]*\\]', w)
    
    if w:
        if w.group()[0] != ']': #For some reason, the predictions rarely prefix the preformative with an ]
            return f"]{w.group()}"
        else:
            return w.group()
        
def g_prs(w):
    
    w = re.sub('\([A-Z]','', w) #Remove root letter
    w = re.search('\+[A-Z]*', w)
    
    if w: return w.group()
    
def g_lex(w):
    
    w = re.sub('\([A-Z\>\<]','', w) #Remove unrealized root letter
    w = re.sub('!?[A-Z\>\<]*=?!','', w) #Remove verbal prefixes and possible disambiguation of prefixes
    w = re.sub('\]?[A-Z]*\]', '', w) #Remove verbal stem
    w = re.sub('&', '', w) #Retain matres lectionis
    w = re.sub('\[/[A-Z\>\<]*', '', w) #Remove nominal suffix from participle and infinitive
    w = re.sub('\[[A-Z\>\<]*','', w) #Remove verbal suffixes
    w = re.sub('/[A-Z\>\<]*','', w) #Remove nominal suffixes
    w = re.sub('\+[A-Z\>\<]*','',w) #Remove pronominal suffixes
    w = re.sub('\~[A-Z\>\<]*','',w) #Remove univalent final
    w = re.sub(':?[a-z]', '', w) #Remove state and verbal stem
    w = re.sub('=','', w) #Remove lexical disambiguation
    
    return w
    
def g_uvf(w):
    
    w = re.sub('\([A-Z]','', w) #Remove preformative
    w = re.search('\~[A-Z]*', w)

    if w: return w.group()
    

# A list of forms for testing purposes
input_forms = ["BR>[", "B-R>CJT/", "!M!RXP[/TK:d", "W:n-!J!>MR[", 'B-!H!](N]BR>[/+M','W-!T=!](N]R>H[','CN(J(M/J=+HM','>B/~J',
               'L-!M>&WR[/W', 'H-CMJ(M/(JM', '!J!HJ(H[', 'W:n-!J!HJ(H[', 'W-L-!!]H]BD&JL[/:c', 'K-DMWT/+NW',
               'Wn-J!(H](J&WCM[','W:n-!J!JFM[W','W-HCT]XWH[','W-HT]BRK[','W->HL/JM~H','(<NC','<YBWN/J+K']

[g_lex(w) for w in input_forms]
# Out:
# ['BR>',
#  'B-R>CJT',
#  'RXP',
#  'W->MR',
#  'B-BR>',
#  'W-R>H',
#  'CN',
#  '>B',
#  'L-M>WR',
#  'H-CMJ',
#  'HJ',
#  'W-HJ',
#  'W-L-BDJL',
#  'K-DMWT',
#  'W-WCM',
#  'W-JFM',
#  'W-XWH',
#  'W-BRK',
#  'W->HL',
#  'NC',
#  '<YBWN']

# %%
pred_feat = [g_lex(SP.api.F.prediction.v(w)) if g_lex(SP.api.F.prediction.v(w)) else 'absent' for w in SP.api.F.otype.s('word')]

# %%
collections.Counter(pred_feat)
# Out:
# Counter({'B': 871,
#          'R>CJT': 3,
#          'BR>': 10,
#          '>LH': 316,
#          '>T': 1180,
#          'H': 1653,
#          'CMJ': 39,
#          'W': 4215,
#          '>RY': 316,
#          'HJ': 213,
#          'THW': 1,
#          'XCK': 8,
#          '<L': 301,
#          'PN': 160,
#          'THWM': 4,
#          'RWX': 12,
#          'MRXP': 1,
#          'MJ': 72,
#          '>MR': 610,
#          '>WR': 9,
#          'R>': 91,
#          'KJ': 291,
#          'VWB': 45,
#          'BDL': 2,
#          'BJN': 74,
#          'QR>': 126,
#          'L': 1360,
#          'JWM': 83,
#          'LJLH': 26,
#          '<RB': 16,
#          'BQR': 35,
#          '>XD': 43,
#          'RQJ<': 9,
#          'TWK': 16,
#          'MBDJL': 1,
#          '<C': 66,
#          '>CR': 422,
#          'M': 369,
#          'TXT': 32,
#          'KN': 56,
#          'CM': 258,
#          'CN': 228,
#          'QW': 1,
#          '>L': 370,
#          'MQWM': 47,
#          'R>H': 28,
#          'JBC': 3,
#          'MQWH': 1,
#          'JM': 91,
#          'DC>': 3,
#          '<CB': 7,
#          'MZRJ<': 2,
#          'ZR<': 63,
#          '<Y': 30,
#          'PRJ': 9,
#          'MJN': 19,
#          'WY>': 8,
#          'CLJCJ': 7,
#          'M>WR': 6,
#          '>JR': 3,
#          'BDJL': 2,
#          'MW<D': 4,
#          'GDL': 26,
#          'GDWL': 23,
#          'MMCL': 2,
#          'QVN': 24,
#          'KWKB': 5,
#          'TN': 73,
#          'MCL': 8,
#          'absent': 121,
#          'RBJ<': 2,
#          'JCRY': 1,
#          'CRY': 6,
#          'NPC': 43,
#          'XJ': 113,
#          '<WP': 22,
#          '<PP': 1,
#          'TNJN': 1,
#          'KL': 390,
#          'RMC': 20,
#          'KNP': 2,
#          'BRK': 72,
#          'PR': 19,
#          'RB': 33,
#          'ML>': 19,
#          'JRBH': 1,
#          'XMJCJ': 2,
#          'TWY>': 1,
#          'BHM': 21,
#          '>DM': 99,
#          'N<C': 2,
#          'YLMN': 1,
#          'K': 155,
#          'DMWTN': 1,
#          'JRD': 9,
#          'DG': 4,
#          'YLM': 3,
#          'ZKR': 24,
#          'QBH': 10,
#          'KBC': 4,
#          'RD': 14,
#          'HNH': 123,
#          'NT': 30,
#          'HJH': 86,
#          '>KL': 85,
#          'JRQ': 2,
#          '<CH': 35,
#          'M>D': 40,
#          'CCJ': 3,
#          'YB>': 4,
#          'LK': 68,
#          'ML>K': 23,
#          'CB': 69,
#          'CBJ<J': 2,
#          'CBJ<': 4,
#          'QDC': 7,
#          'WLD': 9,
#          '<CWT': 11,
#          'JHWH': 160,
#          'CJX': 1,
#          'CD': 49,
#          'VRM': 9,
#          'YMX': 5,
#          'L>': 212,
#          'VJR': 3,
#          '>JN': 39,
#          '<BD': 113,
#          '>D': 1,
#          '<LH': 15,
#          'MN': 52,
#          'CQH': 6,
#          'YR': 8,
#          '<PR': 10,
#          'PX': 1,
#          '>P': 28,
#          'V<': 3,
#          'GN': 14,
#          '<DN': 6,
#          'QDM': 15,
#          'NXMD': 1,
#          'MR>H': 9,
#          'M>KL': 6,
#          'D<': 14,
#          'R<': 73,
#          'NHR': 11,
#          'JY>': 21,
#          'CQ': 18,
#          'PRD': 5,
#          '>RB<': 34,
#          'R>C': 21,
#          'PJCWN': 1,
#          'HW>': 123,
#          'SWBB': 2,
#          'XWJLH': 3,
#          'ZHB': 9,
#          'HJ>': 61,
#          'BDLX': 1,
#          '>BN': 15,
#          'CHM': 1,
#          'CNJ': 9,
#          'GJXWN': 1,
#          'KWC': 4,
#          'CLJC': 3,
#          'HDQL': 1,
#          'HLK': 25,
#          '>CWR': 5,
#          'PRT': 5,
#          'QX': 111,
#          'NJX': 3,
#          'CMR': 11,
#          'Y': 7,
#          'MMN': 21,
#          'MWT': 21,
#          'TMWT': 3,
#          'BD': 14,
#          '<ZR': 3,
#          'NGD': 9,
#          '<WD': 53,
#          'B>': 164,
#          'MH': 40,
#          'MY>': 55,
#          'PL': 13,
#          'TRDM': 1,
#          'JCN': 2,
#          '>X': 188,
#          'YL<': 2,
#          'SGR': 4,
#          'BCR': 28,
#          'BN': 458,
#          'LQX': 28,
#          '>C': 132,
#          'BJ>': 20,
#          'Z>T': 54,
#          'P<M': 11,
#          '<YM': 8,
#          'BCRJ': 2,
#          '>JC': 107,
#          '<ZB': 13,
#          '>B': 197,
#          '>M': 144,
#          'DBQ': 4,
#          '<RM': 2,
#          'BCC': 1,
#          'NXC': 12,
#          '<RWM': 3,
#          'N>KL': 1,
#          'ZH': 87,
#          'G<': 2,
#          'TMWTWN': 1,
#          'JD<': 34,
#          'PQX': 3,
#          '<JN': 85,
#          'HJJ': 15,
#          'T>W': 2,
#          'XMD': 2,
#          'CKJL': 1,
#          'GM': 95,
#          '<M': 120,
#          'HM': 22,
#          'P>': 1,
#          '<LJ': 66,
#          '>NH': 4,
#          'XGR': 1,
#          'CM<': 57,
#          'QWL': 25,
#          'MTHLK': 1,
#          'XB>': 1,
#          '>JKH': 1,
#          '>JR>': 1,
#          '>NKJ': 55,
#          '>XB>': 1,
#          'GJD': 17,
#          '>TH': 61,
#          'YWJ': 3,
#          'BLT': 10,
#          '<MD': 30,
#          'NTN': 25,
#          '<CJT': 27,
#          'HCJNJ': 1,
#          '>RWR': 5,
#          'GXN': 1,
#          '>JB': 4,
#          '>CJT': 1,
#          'CWP': 2,
#          '<QB': 19,
#          'HRB': 5,
#          '>RB': 6,
#          '<YBWN': 3,
#          'RJWN': 1,
#          'TLD': 2,
#          'CWQ': 2,
#          'BJK': 1,
#          '<BWR': 14,
#          '<YWN': 1,
#          'QWY': 1,
#          'DRDR': 1,
#          'YMJX': 1,
#          'Z<T': 1,
#          'LXM': 24,
#          '<D': 85,
#          'CWB': 18,
#          'LQXT': 1,
#          'XWH': 2,
#          'KJTN': 8,
#          '<WR': 2,
#          'LBC': 4,
#          'HN': 30,
#          '<TH': 41,
#          'CLX': 65,
#          'JD': 95,
#          '<WLM': 13,
#          'GRC': 3,
#          'CKN': 8,
#          'KRWB': 1,
#          'LXV': 1,
#          'XRB': 9,
#          'MTHPK': 1,
#          'DRK': 31,
#          'HR': 43,
#          'LD': 50,
#          'QJN': 17,
#          'QNJ': 5,
#          'SP': 6,
#          'HBL': 8,
#          'R<J': 3,
#          'Y>N': 64,
#          'QY': 12,
#          'MNX': 13,
#          'HBJ>': 1,
#          'BKWR': 17,
#          'XLBJHN': 1,
#          'C<': 8,
#          'XR': 10,
#          'LMH': 21,
#          'XRH': 1,
#          'NPL': 6,
#          'LW>': 12,
#          'VJB': 4,
#          'C>T': 9,
#          'PTX': 16,
#          'XV>': 14,
#          'RBY': 5,
#          '>LJ': 170,
#          'QM': 32,
#          'HRG': 14,
#          '>JH': 6,
#          'DM': 12,
#          'Y<Q': 7,
#          'PY': 2,
#          'PJ': 24,
#          'WSJP': 5,
#          'TT': 2,
#          'KX': 3,
#          'N<': 2,
#          'ND': 3,
#          '<WN': 4,
#          'NC>': 3,
#          '>STJR': 1,
#          'LKN': 2,
#          'CB<': 111,
#          '>WT': 5,
#          'HKWT': 2,
#          'Y>': 40,
#          'XNWK': 11,
#          '<JR': 39,
#          '<JRD': 2,
#          'JLD': 61,
#          'MJH>L': 2,
#          'MTWC>L': 2,
#          'LM': 4,
#          'C': 27,
#          'NC': 11,
#          'YL': 7,
#          'BL': 2,
#          'JCB': 14,
#          '>HL': 27,
#          'MQNH': 17,
#          'WBL': 1,
#          'TPC': 2,
#          'KNR': 2,
#          '<GB': 1,
#          'TWBL_QJN': 2,
#          'LVC': 2,
#          'XRC': 1,
#          'BRZL': 1,
#          '>XW': 21,
#          '<MH': 2,
#          'NCJ': 14,
#          'CM<N': 1,
#          'H>ZJN': 1,
#          '>MJR': 1,
#          'PY<': 1,
#          'XBR': 4,
#          '>XR': 100,
#          '>NWC': 9,
#          '>Z': 6,
#          'HXL': 4,
#          'SPR': 15,
#          'TWLD': 11,
#          'BR>M': 1,
#          'CLC': 58,
#          'M>': 67,
#          'WLJD': 59,
#          'DMWT': 1,
#          'CMN': 22,
#          'TC<': 8,
#          'MT': 51,
#          'XMC': 35,
#          '<CR': 54,
#          'QJNN': 4,
#          'MHLL>L': 3,
#          'MHL>L': 2,
#          'CC': 21,
#          'C<JM': 3,
#          'MTWCLX': 5,
#          'NX': 45,
#          'NXM': 9,
#          'M<CJN': 1,
#          '>RRH': 1,
#          'XM': 19,
#          'JPT': 8,
#          'BXR': 2,
#          'JDWN': 1,
#          'GBWR': 4,
#          '>NC': 45,
#          'RBH': 1,
#          'JYR': 2,
#          'MXCB': 1,
#          'LB': 13,
#          'RQ': 13,
#          '<YB': 3,
#          '>MX': 1,
#          'XN': 16,
#          'YDJQ': 7,
#          'MJM': 1,
#          'DRT': 3,
#          'HTHLK': 5,
#          'CXT': 3,
#          'XMS': 4,
#          'CXJT': 10,
#          'MCXJT': 1,
#          'TB': 26,
#          'GPR': 1,
#          'QN': 4,
#          'KPR': 2,
#          'BJT': 111,
#          'XWY': 12,
#          '>RK': 4,
#          'RXB': 6,
#          'QWM': 17,
#          'YHR': 6,
#          '<ML': 2,
#          'YD': 4,
#          'CJM': 11,
#          '>NJ': 44,
#          'MBWL': 12,
#          'G': 1,
#          'BRJT': 28,
#          '>SP': 13,
#          'YWH': 9,
#          'R>J': 14,
#          'DWR': 2,
#          'VHR': 5,
#          'VHWR': 2,
#          'MVJR': 1,
#          'MXJ': 1,
#          'JQWM': 2,
#          'XDC': 12,
#          'BQ<': 4,
#          'M<JN': 1,
#          'NPTX': 3,
#          'GCM': 2,
#          'PT': 6,
#          'YPWR': 2,
#          '>TW': 1,
#          'B<D': 4,
#          'C>': 32,
#          'RM': 1,
#          'GBR': 8,
#          'KS': 3,
#          'GBX': 1,
#          'M<L': 4,
#          'GW<': 5,
#          'CMT': 1,
#          'MX': 2,
#          'C>R': 6,
#          '>K': 12,
#          '<BR': 37,
#          'CK': 2,
#          'SKR': 1,
#          '<': 2,
#          'XSR': 2,
#          'HRV': 1,
#          '<CJR': 2,
#          'XLWN': 2,
#          'JWN': 3,
#          'QL': 4,
#          'JWNH': 2,
#          'MNWX': 2,
#          'KP': 9,
#          'RGL': 12,
#          'XL': 5,
#          '<T': 10,
#          'ZJT': 1,
#          'VRP': 8,
#          'J': 2,
#          'SPH': 5,
#          'R>JCWN': 10,
#          'SR': 7,
#          'MKS': 2,
#          'BCH': 1,
#          'DBR': 134,
#          '>TK': 1,
#          'WYJ>': 9,
#          'MCPX': 13,
#          'MZBX': 13,
#          'RX': 4,
#          'RJX': 4,
#          'QLL': 3,
#          'N<R': 38,
#          'QYJR': 3,
#          'QWR': 2,
#          'QJY': 1,
#          'XRP': 4,
#          'JWMM': 1,
#          'MR>K': 1,
#          'XT': 16,
#          '>DRC': 2,
#          '>DRCN': 1,
#          'CPK': 3,
#          '>TM': 16,
#          'QJM': 3,
#          '>TKM': 2,
#          'KRT': 9,
#          'JHJH': 1,
#          'HCXJT': 2,
#          'DRWT': 1,
#          'QCT': 7,
#          '<NN': 4,
#          '<NNJ': 1,
#          '>ZKR': 1,
#          'JWY>': 1,
#          'KN<N': 47,
#          'NPY': 2,
#          'KRM': 3,
#          'CT': 11,
#          'JJ': 1,
#          'CKR': 12,
#          'GL': 9,
#          '<RW': 5,
#          'GD': 23,
#          'CML': 6,
#          'CKM': 32,
#          '>XRNJT': 2,
#          'JJN': 7,
#          'BRWK': 10,
#          'LMW': 1,
#          'GMR': 2,
#          'MGWG': 1,
#          'MDJ': 1,
#          'WN': 1,
#          'TWBL': 1,
#          'MWCK': 1,
#          'JRS': 1,
#          '>CKNZ': 1,
#          'RJP': 1,
#          'GRM': 1,
#          '>LJC': 1,
#          'TRCJC': 1,
#          'KT': 1,
#          'RWDN': 1,
#          '>J': 2,
#          'GWJ': 27,
#          'MYRJM': 93,
#          'PWV': 2,
#          'SBH': 1,
#          'XWJL': 2,
#          'SB': 3,
#          'R<M': 2,
#          'SBT': 1,
#          'CB>': 4,
#          'DDN': 3,
#          'MRWD': 1,
#          'YJD': 12,
#          'NMRWD': 1,
#          'MMLK': 2,
#          'BBL': 2,
#          '>KD': 1,
#          'KLN': 3,
#          'CN<R': 4,
#          'NJNWH': 2,
#          'RXB_<JR': 1,
#          'KLX': 2,
#          'RSN': 1,
#          'LDJM': 1,
#          'BJM': 1,
#          'PTRS': 1,
#          'KSLX': 1,
#          'PLCT': 8,
#          'KPTR': 1,
#          'YJDWN': 1,
#          'JBWSJ': 2,
#          '>MRJ': 7,
#          'GRGC': 2,
#          'XWJ': 6,
#          '<RWQJ': 1,
#          'SJNJ': 1,
#          '>RWDJ': 1,
#          'YMRJ': 1,
#          'XMTJ': 1,
#          'KN<NJ': 11,
#          'GBWL': 3,
#          '>XRWN': 1,
#          'LCN': 2,
#          '<JLM': 3,
#          '>RPKCD': 7,
#          '>RM': 15,
#          '<WY': 3,
#          'GTR': 1,
#          'MC>': 6,
#          'PLG': 6,
#          'NPLG': 1,
#          '>LMWDD': 1,
#          'CLP': 1,
#          'XYRM': 1,
#          'JRX': 2,
#          '>DWRM': 1,
#          '<JZL': 1,
#          'DQL': 1,
#          '<JBL': 2,
#          '>BJM>L': 1,
#          '>PR': 4,
#          'JWBB': 3,
#          'MWCB': 4,
#          'B>KH': 4,
#          'CP': 3,
#          'NS<': 5,
#          'HBH': 5,
#          'LBN': 60,
#          'CRP': 2,
#          'CRPH': 1,
#          'XJMR': 3,
#          'NBNH': 1,
#          'MGDL': 3,
#          'NPWY': 1,
#          'HXLM': 1,
#          'BYR': 2,
#          'ZMN': 1,
#          'RDH': 3,
#          'BLH': 2,
#          'CPT': 6,
#          'XDL': 3,
#          'BLL': 1,
#          'HPJY': 1,
#          'WLJ': 1,
#          'CRWG': 8,
#          'NXWR': 18,
#          'M>T': 3,
#          'TRX': 7,
#          '>BRM': 59,
#          'HRN': 7,
#          'LWV': 33,
#          'MWLD': 10,
#          'KCD': 4,
#          'CR': 74,
#          'MLK': 63,
#          'SKH': 1,
#          '<QR': 4,
#          'XRN': 5,
#          '<CK': 1,
#          '>BRK': 7,
#          'HWJ': 4,
#          'MBRK': 2,
#          'MQLL': 1,
#          '>>R': 1,
#          'RKWC': 11,
#          'RKC': 5,
#          '<CW': 80,
#          '>LWN': 7,
#          'MWR>': 2,
#          '>TN': 10,
#          '<TQ': 2,
#          'V': 7,
#          'BJT_>L': 8,
#          '<J': 2,
#          'S<': 7,
#          'HLWK': 1,
#          'NGB': 7,
#          'R<B': 25,
#          'GWR': 4,
#          'KBD': 12,
#          'QRJB': 1,
#          'BW>': 26,
#          'N>': 77,
#          'KH': 12,
#          'LM<N': 7,
#          'JVB': 5,
#          'GLJ': 1,
#          'JPH': 2,
#          'PR<H': 94,
#          'HLL': 1,
#          'HJJVB': 1,
#          'CPX': 29,
#          'XMR': 11,
#          '>TNWT': 1,
#          'GML': 28,
#          'NG<': 5,
#          'YW': 6,
#          'KSP': 44,
#          'MS<': 1,
#          'TXL': 4,
#          'C>H': 1,
#          'CBT': 8,
#          'JXDW': 6,
#          'RJB': 3,
#          'PRZJ': 3,
#          'MRJB': 1,
#          '>NXNW': 18,
#          'HPRD': 2,
#          'CM>L': 7,
#          'JMJN': 7,
#          'KKR': 7,
#          'JRDN': 6,
#          'MCQ': 8,
#          'CX': 1,
#          'SDM': 20,
#          '<MR': 8,
#          'Y<R': 6,
#          '<R': 14,
#          'HWH': 7,
#          'YPWN': 3,
#          'CMTJ': 3,
#          'WKL': 15,
#          'MNWT': 1,
#          'JMN': 2,
#          'MMR>': 10,
#          'XBRWN': 5,
#          '>MRPL': 2,
#          '>RJW': 2,
#          '>LSR': 2,
#          'KDR_<MR': 5,
#          'D<L': 2,
#          'MLXM': 2,
#          'BR<': 1,
#          'BRC<': 1,
#          'CN>B': 1,
#          'CM_>BD': 1,
#          'YBW>': 2,
#          'BL<': 7,
#          '<MQ': 7,
#          'CDJ': 7,
#          'MLX': 2,
#          'MRD': 1,
#          'RP>': 4,
#          '<CTR_QRN': 1,
#          'ZWZ': 1,
#          '>JM': 4,
#          'CBJ': 3,
#          'QRJT': 1,
#          'XRJ': 6,
#          'C<JR': 12,
#          '>JL_PR>N': 1,
#          'MDBR': 8,
#          '<JN_MCPV': 1,
#          '<MLQJ': 1,
#          'XYYWN_TMR': 1,
#          '<RK': 2,
#          'CDJM': 1,
#          'B>RWT': 3,
#          'NS': 6,
#          'PLJV': 1,
#          '<BRJ': 2,
#          'CKWL': 2,
#          '<NRM': 2,
#          'B<LJ': 2,
#          'DQ': 6,
#          'XNJK': 1,
#          'JLJD': 5,
#          'RDP': 5,
#          'DN': 8,
#          'XLQ': 8,
#          'XWB': 1,
#          'DMCQ': 2,
#          'CJB': 19,
#          'CWJ': 1,
#          'MLK_YDQ': 1,
#          'CLM': 4,
#          'JN': 1,
#          'KHN': 7,
#          'QNH': 10,
#          'MGN': 2,
#          'YRJ': 3,
#          'M<CR': 1,
#          'TNH': 3,
#          'HRMTJ': 1,
#          'XWV': 1,
#          'N<L': 2,
#          'BL<D': 3,
#          'MXZH': 1,
#          'JR>': 23,
#          '>DNJ': 39,
#          '>LJ<ZR': 1,
#          'JRJC': 1,
#          'JRC': 7,
#          'M<JK': 3,
#          'HBV': 1,
#          'H>MN': 2,
#          'XCB': 4,
#          'YDQ': 6,
#          'T': 9,
#          'RC': 2,
#          '>D<': 3,
#          '>JRJCN': 1,
#          '<GL': 5,
#          'MCLC': 3,
#          '<Z': 13,
#          '>JL': 6,
#          'R': 2,
#          'GWZL': 1,
#          'BTR': 2,
#          'TWR': 2,
#          'BTRW': 1,
#          '<JV': 1,
#          'PGR': 1,
#          'CMC': 6,
#          'RDM': 1,
#          '>BR': 1,
#          'GR': 9,
#          '<N': 17,
#          'CLWM': 17,
#          'QBR': 38,
#          'RBJ<J': 1,
#          'JCWB': 1,
#          '<LV': 1,
#          'NWR': 1,
#          '<CN': 1,
#          'LPJD': 1,
#          'GZR': 1,
#          'N': 2,
#          'QJNJ': 1,
#          'QNZJ': 1,
#          'QDMWNJ': 1,
#          'XTJ': 10,
#          'MYRJT': 4,
#          'HGR': 12,
#          '<YR': 3,
#          '>WLJ': 12,
#          '>BNH': 2,
#          'CRJ': 3,
#          'XJQ': 1,
#          'CPV': 5,
#          '<NH': 14,
#          'BRX': 9,
#          'CWR': 6,
#          '>WJ': 1,
#          '<NJ': 5,
#          'CM<>L': 11,
#          'PRH': 2,
#          'HLM': 1,
#          'B>R': 33,
#          'LXJ_R>H': 3,
#          'BRD': 1,
#          'JCM<>L': 9,
#          'TMJM': 1,
#          '>TNH': 2,
#          '>RBH': 1,
#          'HMWN': 2,
#          '>BRHM': 139,
#          'PRJT': 2,
#          'MM': 5,
#          'MGR': 4,
#          '>XZ': 14,
#          'DR': 2,
#          'HMWL': 2,
#          'ML': 8,
#          '<RL': 7,
#          'HJTH': 1,
#          'BJNJ': 1,
#          'MWL': 6,
#          'MQN': 16,
#          'NKR': 4,
#          'JL': 1,
#          'BCRK': 2,
#          'CMJNJ': 1,
#          'HPR': 1,
#          'YXQ': 14,
#          '>WLJD': 1,
#          'CRH': 3,
#          'XJH': 5,
#          '>BL': 7,
#          'JYXQ': 75,
#          'RBJ': 5,
#          'HML': 2,
#          'YB': 11,
#          'RY': 10,
#          'XW': 2,
#          'M<V': 12,
#          'RXY': 5,
#          'C<JN': 1,
#          'S<D': 1,
#          'LBB': 4,
#          'MHR': 14,
#          'SJM': 1,
#          'QMX': 1,
#          'SLT': 1,
#          'LWC': 1,
#          '<G': 1,
#          'RK': 5,
#          'XM>': 1,
#          'XLB': 3,
#          '>CWB': 3,
#          '>XRJW': 1,
#          'ZQN': 20,
#          '>RX': 3,
#          'QRB': 12,
#          '<DNH': 1,
#          '>MNM': 2,
#          '>LD': 1,
#          'JPL>': 1,
#          'KXC': 1,
#          'CQP': 3,
#          'CLXM': 1,
#          '<YWM': 1,
#          'MCPV': 3,
#          '>RDH': 1,
#          'GC': 12,
#          'RC<': 3,
#          'JC': 20,
#          'XLJLH': 4,
#          'MJT': 10,
#          '<BWRM': 1,
#          'W>L': 2,
#          '>DN': 40,
#          'JXSRWN': 1,
#          'XMCJM': 1,
#          'YDQJM': 1,
#          'XMCH': 1,
#          'TCXJ': 1,
#          'J>MR': 1,
#          '>CXJT': 1,
#          '>MY>': 1,
#          'C<R': 11,
#          'JQM': 1,
#          'QR>TM': 1,
#          'CTX': 18,
#          'SWR': 2,
#          'LJN': 5,
#          'NLJN': 1,
#          'PYR': 3,
#          'MCTH': 6,
#          'MYW': 1,
#          'CKB': 21,
#          'QYH': 5,
#          'ND<': 2,
#          'DLT': 3,
#          'RJ<': 4,
#          '>THN': 1,
#          'HL>H': 1,
#          'NRJ<': 1,
#          'CBR': 21,
#          '>NWCJM': 1,
#          'BJ': 2,
#          'HKW': 1,
#          'SNWR': 1,
#          'PH': 4,
#          'XTN': 3,
#          'MYXQ': 3,
#          'XTNJW': 1,
#          'KMW': 3,
#          'CXR': 3,
#          '>JY': 1,
#          'MHMH': 1,
#          'XZQ': 6,
#          '>NWCJ': 1,
#          'XML': 1,
#          'HMLV': 3,
#          'BV': 2,
#          'XSD': 11,
#          'MLV': 2,
#          'QRWB': 2,
#          'NWS': 1,
#          'MY<R': 3,
#          'PKJ': 1,
#          'GPRJT': 1,
#          '>': 5,
#          'HPK': 2,
#          'NYB': 1,
#          'QJVWR': 2,
#          'KBCN': 1,
#          '>PK': 1,
#          'M<R': 11,
#          'BKJR': 6,
#          'Y<JR': 10,
#          '>BJN': 12,
#          'NXJ': 5,
#          'CQJN': 5,
#          '>BJHN': 3,
#          'MXR': 2,
#          '>MC': 3,
#          'CQJ': 1,
#          'MW>B': 3,
#          'BN_<M': 1,
#          '<MWN': 1,
#          'GRR': 6,
#          '>BJMLK': 24,
#          'XLWM': 20,
#          'HNK': 1,
#          '>DW': 4,
#          'B<JL': 1,
#          'B<L': 2,
#          'TM': 6,
#          'NQJWN': 1,
#          '>XC': 1,
#          'HCB': 2,
#          'NBJ>': 1,
#          'PLL': 3,
#          '>ZN': 7,
#          'M<C': 4,
#          'J<CWN': 1,
#          'HRGWN': 1,
#          '<H': 1,
#          '<CJN': 2,
#          '>LP': 3,
#          'KSWT': 1,
#          'WKX': 2,
#          'JRP>': 1,
#          '>LHJM': 1,
#          'RXM': 6,
#          'PQD': 9,
#          'HWLD': 1,
#          'MLL': 1,
#          'HJNJQH': 1,
#          'BNH': 3,
#          'JR<': 1,
#          'CLJ': 1,
#          'CXJ': 1,
#          'HRXQ': 1,
#          'MVW': 1,
#          '>R>H': 5,
#          'BK': 14,
#          ...})

# %% [markdown]
# ## 3. Merge data:

# %%
df = pd.DataFrame([pred_feat, MT_feat, MT_parsing]).T
df.columns = ['pred_feat','MT_feat','MT_parsing']
df
# Out:
#       pred_feat MT_feat MT_parsing
# 0             B       B       True
# 1         R>CJT   R>CJT       True
# 2           BR>     BR>       True
# 3           >LH     >LH       True
# 4            >T      >T       True
# ...         ...     ...        ...
# 29045       WCM   False
# 29046         B       B       True
# 29047       >RN   False
# 29048         B       B       True
# 29049     MYRJM   MYRJM       True
#
# [29050 rows x 3 columns]

# %%
feat_result = []

for n, row in df.iterrows():
    
    if not row['MT_parsing']:
        feat_result.append(row['pred_feat'])
    else:
        feat_result.append(row['MT_feat'])
        
feat_result = [re.sub('absent', '', w) for w in feat_result]    
df[FEATURE] = feat_result

# %% [markdown]
# ## Export

# %%
FEATURE
# Out:
# 'g_lex'

# %%
export_df = df[[FEATURE,'MT_parsing']]
export_df.to_csv(f'./data/{FEATURE}.csv', index=0)
